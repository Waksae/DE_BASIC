# %%
import requests
import pandas as pd

API_KEY = '4eLk73kRBb1JohqtK9i513NajiNHHWpvG0cUtUzwRRuFubxNdKZdBz+XVn8aIc0Xg+ssFEbJt8xSavqerHVHPA=='
LAWD_CD = '11110'
DEAL_YMD = '202405'

# 학교명 호출 함수
def get_info(API_KEY, LAWD_CD, DEAL_YMD):
    url = 'http://apis.data.go.kr/1613000/RTMSDataSvcAptTradeDev/getRTMSDataSvcAptTradeDev'
    params = {
        'LAWD_CD' : LAWD_CD,
        'DEAL_YMD' : DEAL_YMD,
        'serviceKey' : API_KEY,
        'pageNo' : 1,
        'numOfRows' : 100,
        '_type': 'json'
    }
    try:
        res = requests.get(url, params = params, timeout = 5)
        print(f'응답코드 : {res.status_code}')
        # print(f'응답본문 : {res.text}')
        if res.status_code == 200:
            data = res.json()
            return data['response']['body']
        else:
            print('응답 없음', res.text)
    except Exception as e:
        print(f"조회 오류 : {e}")
    return "조회 불가"

raw_data = get_info(API_KEY, LAWD_CD, DEAL_YMD)

cleaned_data = []
for i in raw_data['items']['item'] :
    cleaned_data.append({
        "행정구역" : f"{i['estateAgentSggNm']} {i['umdNm']}",
        "아파트 이름" : i['aptNm'],
        "아파트 동" : i['aptDong'],
        "실거래가" : f"{i['dealAmount']}만원",
        "거래유형" : i['dealingGbn'],
        "전용면적" : f"{i['excluUseAr']} m2"
})
df = pd.DataFrame(cleaned_data)

df.to_csv("24년 5월 서울 실거래정보.csv", index=False, encoding="utf-8-sig")
print("CSV 저장 완료: 24년 5월 서울 실거래정보.csv")

df
# Out:
# 응답코드 : 200
# CSV 저장 완료: 24년 5월 서울 실거래정보.csv
#                   행정구역               아파트 이름  아파트 동       실거래가  거래유형  \
# 0           서울 종로구 창신동                창신쌍용2    201   57,000만원  중개거래
# 1           서울 종로구 연건동                이화에수풀  이화에수풀   18,000만원  중개거래
# 2                  숭인동               에비뉴청계Ⅰ      .   33,280만원   직거래
# 3                  숭인동               에비뉴청계Ⅰ      .   23,400만원   직거래
# 4           서울 종로구 교북동           경희궁자이(4단지)    402  108,000만원  중개거래
# ..                 ...                  ...    ...        ...   ...
# 57          서울 종로구 내수동             경희궁파크팰리스    101  148,000만원  중개거래
# 58  서울 마포구, 서울 종로구 사직동  광화문스페이스본(101동~105동)    105  170,000만원  중개거래
# 59         서울 종로구 명륜1가                  렉스빌         120,000만원  중개거래
# 60          서울 종로구 사직동  광화문스페이스본(101동~105동)    101  138,000만원  중개거래
# 61          서울 종로구 홍파동           경희궁자이(2단지)    204  164,000만원  중개거래
#
#           전용면적
# 0      54.7 m2
# 1     16.98 m2
# 2     24.52 m2
# 3     18.41 m2
# 4    45.879 m2
# ..         ...
# 57   103.77 m2
# 58   131.44 m2
# 59   135.79 m2
# 60    94.51 m2
# 61  59.8547 m2
#
# [62 rows x 6 columns]
